# %% [markdown]
# # M1 - Python TD 2
# ## Chaînes de caractères, listes, dictionnaires ...

# %% [markdown]
# ### Exercice 1

# %%
def is_palindrome(word : str) :
    return word == word[::-1]

# %%
print(is_palindrome("chaine"), is_palindrome("kayak"))
# Out:
# False True

# %%
def is_pangram(word : str) :
    return 26 == len(set([letter.lower() for letter in word if letter.isalpha()]))

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"

# %%
print(is_pangram(alphabet))
print(is_pangram("cfo"))
# Out:
# True
# False

# %%
pangram = "The quick brown fox jumps over the lazy dog, ou encore Portez ce vieux whisky au juge blond qui fume."
is_pangram(pangram)
# Out:
# True

# %%
def remove_adjacent(liste : list) :
    return [liste[i] for i in range (len(liste) - 1) if liste[i+1] != liste[i]] + liste[-1:]

# %%
remove_adjacent([1,2,2,3,3,1])
# Out:
# [1, 2, 3, 1]

# %%
def digits_sum(nombre : int) :
    return sum([int(digit) for digit in str(nombre)])

# %%
digits_sum(950)
# Out:
# 14

# %%
digits_sum(133)
# Out:
# 7

# %% [markdown]
# ### Exercice 2

# %%
def isLegal(word : str) :
    legal = "izehsglbdo"
    for letter in word :
        if letter not in legal :
            return False
    return True

# %%
def mot_chiffre(dico):
    f=open(dico,encoding="ISO-8859-1")
    data = f.read().split()
    res = [word for word in data if isLegal(word)]
    f.close()
    return res

# %%
dico = "liste.de.mots.francais.frgut.txt"
mot_chiffre(dico)
# Out:
# ['beige',
#  'beiges',
#  'bel',
#  'belge',
#  'belges',
#  'belle',
#  'belles',
#  'bibi',
#  'bibis',
#  'bible',
#  'bibles',
#  'bide',
#  'bides',
#  'bielle',
#  'bielles',
#  'bigle',
#  'bigles',
#  'biglez',
#  'bigliez',
#  'bile',
#  'biles',
#  'bilez',
#  'biliez',
#  'bill',
#  'bille',
#  'billes',
#  'bills',
#  'biologie',
#  'biologies',
#  'bis',
#  'bisbille',
#  'bisbilles',
#  'bise',
#  'bises',
#  'bisez',
#  'bisiez',
#  'bisse',
#  'bisses',
#  'bissez',
#  'bissiez',
#  'bled',
#  'bleds',
#  'blesse',
#  'blesses',
#  'blessez',
#  'blessiez',
#  'bob',
#  'bobo',
#  'bobos',
#  'bobs',
#  'bobsleigh',
#  'bobsleighs',
#  'boghei',
#  'bogheis',
#  'bogie',
#  'bogies',
#  'boille',
#  'boilles',
#  'bois',
#  'boise',
#  'boises',
#  'boisez',
#  'boisiez',
#  'bol',
#  'boldo',
#  'boldos',
#  'bolide',
#  'bolides',
#  'bols',
#  'boss',
#  'bosse',
#  'bosselez',
#  'bosseliez',
#  'bosselle',
#  'bosselles',
#  'bosses',
#  'bossez',
#  'bossiez',
#  'de',
#  'des',
#  'desselle',
#  'desselles',
#  'dessellez',
#  'desselliez',
#  'dessille',
#  'dessilles',
#  'dessillez',
#  'dessilliez',
#  'dessole',
#  'dessoles',
#  'dessolez',
#  'dessoliez',
#  'dg',
#  'diesel',
#  'diesels',
#  'diode',
#  'diodes',
#  'dis',
#  'dise',
#  'dises',
#  'disiez',
#  'disse',
#  'disses',
#  'dissiez',
#  'dl',
#  'do',
#  'dodo',
#  'dodos',
#  'doge',
#  'doges',
#  'dois',
#  'dol',
#  'dole',
#  'doles',
#  'dolez',
#  'doliez',
#  'dols',
#  'dos',
#  'dose',
#  'doses',
#  'dosez',
#  'dosiez',
#  'dosse',
#  'dosses',
#  'ego',
#  'eh',
#  'elle',
#  'elles',
#  'es',
#  'esse',
#  'esses',
#  'gel',
#  'gelez',
#  'geliez',
#  'gels',
#  'gesse',
#  'gesses',
#  'ghilde',
#  'ghildes',
#  'giboie',
#  'giboies',
#  'gigolo',
#  'gigolos',
#  'gilde',
#  'gildes',
#  'gille',
#  'gilles',
#  'gis',
#  'gisez',
#  'gisiez',
#  'glisse',
#  'glisses',
#  'glissez',
#  'glissiez',
#  'globe',
#  'globes',
#  'glose',
#  'gloses',
#  'glosez',
#  'glosiez',
#  'go',
#  'gobe',
#  'gobes',
#  'gobez',
#  'gobie',
#  'gobies',
#  'gobiez',
#  'gode',
#  'godes',
#  'godez',
#  'godiez',
#  'godille',
#  'godilles',
#  'godillez',
#  'godilliez',
#  'gogo',
#  'gogos',
#  'gosse',
#  'gosses',
#  'hello',
#  'hi',
#  'hie',
#  'hies',
#  'hisse',
#  'hisses',
#  'hissez',
#  'hissiez',
#  'ho',
#  'hobbies',
#  'holoside',
#  'holosides',
#  'ibis',
#  'ide',
#  'ides',
#  'idole',
#  'idoles',
#  'igloo',
#  'igloos',
#  'il',
#  'illisible',
#  'illisibles',
#  'ils',
#  'iode',
#  'iodes',
#  'iodez',
#  'iodiez',
#  'iodle',
#  'iodles',
#  'iodlez',
#  'iodliez',
#  'isoglosse',
#  'isoglosses',
#  'isole',
#  'isoles',
#  'isolez',
#  'isoliez',
#  'le',
#  'lebel',
#  'lebels',
#  'legs',
#  'lei',
#  'les',
#  'li',
#  'libelle',
#  'libelles',
#  'libellez',
#  'libelliez',
#  'libido',
#  'libidos',
#  'lido',
#  'lidos',
#  'lie',
#  'lied',
#  'lieds',
#  'lies',
#  'liesse',
#  'liesses',
#  'liez',
#  'lige',
#  'liges',
#  'ligie',
#  'ligies',
#  'liiez',
#  'lis',
#  'lise',
#  'lises',
#  'lisez',
#  'lisible',
#  'lisibles',
#  'lisiez',
#  'lisse',
#  'lisses',
#  'lissez',
#  'lissiez',
#  'lob',
#  'lobbies',
#  'lobe',
#  'lobes',
#  'lobez',
#  'lobiez',
#  'lobs',
#  'lods',
#  'loess',
#  'loge',
#  'loges',
#  'logez',
#  'logiez',
#  'logis',
#  'logo',
#  'logos',
#  'loi',
#  'lois',
#  'loisible',
#  'loisibles',
#  'lolo',
#  'lolos',
#  'obel',
#  'obels',
#  'oblige',
#  'obliges',
#  'obligez',
#  'obligiez',
#  'obole',
#  'oboles',
#  'ode',
#  'odes',
#  'oeil',
#  'oh',
#  'oie',
#  'oies',
#  'oille',
#  'oilles',
#  'ois',
#  'oiselez',
#  'oiseliez',
#  'oiselle',
#  'oiselles',
#  'os',
#  'ose',
#  'oseille',
#  'oseilles',
#  'oses',
#  'osez',
#  'oside',
#  'osides',
#  'osiez',
#  'se',
#  'seigle',
#  'seigles',
#  'seille',
#  'seilles',
#  'seize',
#  'sel',
#  'selle',
#  'selles',
#  'sellez',
#  'selliez',
#  'sels',
#  'ses',
#  'sessile',
#  'sessiles',
#  'si',
#  'sied',
#  'sigle',
#  'sigles',
#  'sil',
#  'silo',
#  'silos',
#  'sils',
#  'sis',
#  'sise',
#  'sises',
#  'soi',
#  'soie',
#  'soies',
#  'sois',
#  'sol',
#  'solde',
#  'soldes',
#  'soldez',
#  'soldiez',
#  'sole',
#  'soleil',
#  'soleils',
#  'soles',
#  'solide',
#  'solides',
#  'solo',
#  'solos',
#  'sols',
#  'sosie',
#  'sosies',
#  'zellige',
#  'zelliges',
#  'zibe',
#  'zibes',
#  'zibez',
#  'zibiez',
#  'zig',
#  'zigs',
#  'zizi',
#  'zizis',
#  'zoo',
#  'zoologie',
#  'zoologies',
#  'zoos',
#  'zozo',
#  'zozos']

# %%
def inChain(chain : str, word : str) :
    temp = list(chain)
    for letter in word :
        if letter not in temp :
            return False
        temp.remove(letter)
    return True


def lookup(chain : str) :
    f=open("liste.de.mots.francais.frgut.txt", encoding="ISO-8859-1")
    data = f.read().split()
    allWords = [word for word in data if inChain(chain, word.upper())]
    f.close()
    allWords.sort(key=len, reverse=True)
    lenMax = len(allWords[0])
    res = [word for word in allWords if len(word) == lenMax]
    return res

# %%
lookup('XWRDYTRERASZ')
# Out:
# ['dartres', 'retards', 'steward']

# %% [markdown]
# ### Exercice 3

# %%
def original(text) :
    f = open(text, encoding="latin1")
    data = f.read().split()
    f.close()
    return ' '.join([word for word in data])

# %%
from random import shuffle

def twister(word : str) :
    if (not word.isalpha() or len(word) <= 3) : return word
    letters = list(word)[1:-1]
    shuffle(letters)
    return word[0] + ''.join(letters) + word[-1]

def text_twist(text) :
    f = open(text, encoding="latin1")s
    data = f.read().split()
    f.close()
    allWords = [twister(word) for word in data]

    return ' '.join(allWords)

# %%
long = 'long.txt'
harmonie = 'harmonie.txt'

# %%
#original(fichier)

# %%
text_twist(harmonie)
# Out:
# "Honarime du sior Vcoii vnier les tepms où vbinrat sur sa tige Cqhuae fluer s'évapore aisni qu'un eescinonr ; Les snos et les pmarufs truonnet dnas l'air du soir ; Vsale mlécqnloauie et lrnoeuguax vgreite ! Chuqae fluer s'évapore ainsi qu'un ecosnnier ; Le viooln frimét comme un cuoer qu'on aflifge ; Vslae mauléqcnoile et luuaeogrnx vrtigee ! Le ciel est trtise et beau comme un gnrad reposoir. Le vloion fméirt cmome un couer qu'on afflige, Un ceuor tendre, qui hait le nnaét vtase et noir ! Le ceil est titrse et baeu cmmoe un ganrd reipsoor ; Le seioll s'est noyé dnas son sang qui se fige. Un couer tendre, qui hait le nénat vaste et noir, Du pssaé lumuienx rlicuelee tout vietgse ! Le seliol s'est nyoé dnas son snag qui se fige... Ton sonieuvr en moi luit cmmoe un otesniosr !"

